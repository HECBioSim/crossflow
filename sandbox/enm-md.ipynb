# %%
import mdtraj as mdt
import numpy as np

# %%
t = mdt.load('2rjy.pdb')
sel = t.topology.select('protein')
tsel = t.atom_slice(sel)
print(tsel)
# Out:
# <mdtraj.Trajectory with 1 frames, 514 atoms, 64 residues, and unitcells>

# %%
tsel[0].save('tsel0.pdb')

# %%
from mdplus import utils
import networkx as nx

# %%
bonds = [(b[0].index, b[1].index) for b in tsel.topology.bonds]

# %%
G = nx.Graph()
for b in bonds:
    G.add_edge(b[0], b[1])

# %%
from scipy.spatial import KDTree

# %%
kdt = KDTree(tsel.xyz[0])

# %%
print(kdt.query_pairs(0.1))
# Out:
# set()

# %%
b13 = [(a[0], a[2]) for a in utils.get_angles(G)]

# %%
print(b13)
# Out:
# [(1, 3), (1, 8), (1, 5), (2, 4), (2, 9), (3, 8), (4, 6), (4, 7), (0, 2), (0, 4), (6, 7), (8, 10), (8, 12), (9, 11), (9, 17), (9, 13), (10, 12), (10, 18), (11, 17), (12, 14), (13, 15), (13, 16), (15, 16), (17, 19), (17, 21), (18, 20), (18, 24), (18, 23), (18, 22), (19, 21), (19, 25), (20, 24), (22, 23), (24, 26), (24, 28), (25, 27), (25, 35), (25, 29), (26, 28), (26, 36), (26, 41), (27, 35), (28, 30), (28, 31), (29, 32), (29, 33), (30, 34), (30, 31), (32, 33), (31, 34), (35, 37), (35, 39), (35, 40), (36, 38), (36, 42), (36, 40), (36, 41), (37, 39), (37, 43), (38, 42), (39, 41), (42, 44), (42, 46), (43, 45), (43, 50), (43, 47), (44, 46), (44, 51), (45, 50), (46, 48), (46, 49), (48, 49), (50, 52), (50, 54), (51, 53), (51, 58), (51, 55), (52, 54), (52, 59), (53, 58), (54, 56), (54, 57), (56, 57), (58, 60), (58, 62), (59, 61), (59, 65), (59, 63), (59, 64), (60, 62), (60, 66), (61, 65), (63, 64), (65, 67), (65, 69), (66, 68), (66, 73), (66, 70), (67, 69), (67, 74), (68, 73), (69, 71), (69, 72), (71, 72), (73, 75), (73, 77), (74, 76), (74, 80), (74, 78), (74, 79), (75, 77), (75, 81), (76, 80), (78, 79), (80, 82), (80, 84), (81, 83), (81, 88), (81, 85), (82, 84), (82, 89), (83, 88), (84, 87), (84, 86), (86, 87), (88, 90), (88, 92), (89, 91), (89, 95), (89, 94), (89, 93), (90, 92), (90, 96), (91, 95), (93, 94), (95, 97), (95, 99), (96, 98), (96, 100), (97, 99), (97, 101), (98, 100), (100, 102), (100, 104), (101, 103), (101, 105), (102, 104), (102, 106), (103, 105), (105, 107), (105, 109), (106, 108), (106, 114), (106, 110), (107, 109), (107, 115), (108, 114), (109, 111), (110, 112), (110, 113), (112, 113), (114, 116), (114, 118), (115, 117), (115, 122), (115, 119), (116, 118), (116, 123), (117, 122), (118, 120), (118, 121), (120, 121), (122, 124), (122, 126), (123, 125), (123, 130), (123, 127), (124, 126), (124, 131), (124, 136), (125, 130), (126, 128), (126, 129), (128, 129), (130, 132), (130, 134), (130, 135), (131, 133), (131, 
# (502, 505)
# (258, 266)
# (8, 11)
# (321, 327)
# (24, 220)
# (107, 110)
# (139, 142)
# (369, 375)
# (207, 462)
# (391, 399)
# (423, 431)
# (457, 465)
# (331, 361)
# (162, 180)
# (294, 299)
# (400, 438)
# (361, 366)
# (353, 362)
# (103, 107)
# (420, 429)
# (183, 193)
# (194, 202)
# (260, 268)
# (392, 429)
# (367, 372)
# (97, 102)
# (109, 113)
# (230, 236)
# (252, 259)
# (38, 43)
# (108, 115)
# (170, 175)
# (466, 474)
# (229, 238)
# (350, 361)
# (133, 139)
# (392, 399)
# (177, 181)
# (457, 464)
# (103, 106)
# (162, 169)
# (261, 291)
# (194, 201)
# (202, 205)
# (235, 238)
# (312, 314)
# (261, 268)
# (3, 9)
# (68, 74)
# (98, 102)
# (331, 340)
# (124, 132)
# (220, 221)
# (180, 185)
# (341, 344)
# (374, 377)
# (345, 350)
# (466, 473)
# (238, 242)
# (12, 15)
# (37, 44)
# (341, 347)
# (392, 398)
# (115, 120)
# (203, 210)
# (45, 51)
# (26, 37)
# (151, 153)
# (162, 168)
# (251, 254)
# (61, 93)
# (269, 279)
# (73, 80)
# (439, 444)
# (98, 114)
# (472, 477)
# (475, 482)
# (235, 240)
# (117, 118)
# (88, 91)
# (183, 184)
# (154, 157)
# (438, 446)
# (242, 247)
# (385, 411)
# (38, 44)
# (42, 50)
# (301, 310)
# (342, 347)
# (123, 136)
# (45, 73)
# (252, 286)
# (237, 243)
# (241, 249)
# (294, 489)
# (348, 352)
# (27, 37)
# (141, 144)
# (230, 338)
# (167, 174)
# (210, 215)
# (440, 448)
# (200, 207)
# (269, 278)
# (73, 79)
# (432, 439)
# (217, 222)
# (174, 180)
# (313, 316)
# (80, 85)
# (339, 345)
# (81, 86)
# (143, 146)
# (17, 20)
# (309, 313)
# (247, 338)
# (342, 346)
# (183, 209)
# (65, 73)
# (368, 376)
# (238, 266)
# (68, 199)
# (397, 411)
# (497, 498)
# (238, 243)
# (456, 465)
# (286, 291)
# (17, 23)
# (348, 351)
# (27, 36)
# (83, 89)
# (382, 385)
# (385, 390)
# (429, 438)
# (441, 448)
# (493, 495)
# (463, 472)
# (19, 22)
# (11, 18)
# (45, 52)
# (414, 421)
# (152, 155)
# (484, 485)
# (174, 179)
# (137, 148)
# (200, 209)
# (244, 251)
# (177, 462)
# (25, 41)
# (376, 384)
# (159, 162)
# (148, 152)
# (194, 217)
# (76, 81)
# (412, 417)
# (391, 394)
# (125, 131)
# (424, 427)
# (253, 257)
# (472, 481)
# (17, 22)
# (95, 98)
# (38, 58)
# (441, 447)
# (227, 230)
# (293, 296)
# (90, 94)
# (116, 124)
# (481, 486)
# (212, 218)
# (244, 250)
# (20, 25)
# (432, 463)
# (108, 110)
# (366, 374)
# (377, 383)
# (432, 440)
# (266, 277)
# (298, 309)
# (277, 286)
# (449, 455)
# (280, 287)
# (321, 324)
# (324, 329)
# (209, 217)
# (24, 27)
# (61, 66)
# (385, 391)
# (397, 402)
# (105, 114)
# (117, 124)
# (160, 165)
# (400, 412)
# (377, 428)
# (53, 80)
# (289, 292)
# (323, 326)
# (130, 133)
# (414, 422)
# (326, 345)
# (60, 63)
# (457, 494)
# (140, 149)
# (280, 309)
# (0, 3)
# (88, 93)
# (328, 339)
# (162, 163)
# (125, 132)
# (114, 122)
# (155, 160)
# (177, 178)
# (490, 494)
# (291, 298)
# (321, 326)
# (364, 367)
# (51, 56)
# (117, 123)
# (161, 165)
# (423, 430)
# (413, 422)
# (220, 228)
# (24, 29)
# (35, 38)
# (444, 471)
# (316, 322)
# (91, 96)
# (186, 189)
# (504, 507)
# (183, 192)
# (56, 87)
# (249, 258)
# (75, 78)
# (53, 59)
# (108, 111)
# (377, 384)
# (152, 158)
# (481, 490)
# (384, 391)
# (122, 125)
# (454, 463)
# (217, 227)
# (484, 491)

# %%
from scipy.spatial.distance import pdist, squareform

# %%
dm = squareform(pdist(tsel.xyz[0]))

# %%
restraints = []
for b in bonds:
    restraints.append([b[0], b[1], dm[b[0], b[1]]])

# %%
print(restraints)
# Out:
# [[0, 1, 0.14918077952939188], [0, 2, 0.24905379119200885], [0, 4, 0.2473734843723385], [1, 2, 0.1535107540864744], [1, 3, 0.24105324865754596], [1, 4, 0.15339492134519878], [1, 5, 0.262420312629529], [1, 8, 0.24398782433743535], [2, 3, 0.1235650705318628], [2, 4, 0.2514117207406927], [2, 8, 0.1333455988833309], [2, 9, 0.24640257450917272], [3, 8, 0.22592779882640018], [4, 5, 0.1536283993963965], [4, 6, 0.25085405997051774], [4, 7, 0.2507226237272199], [5, 6, 0.1526752415218797], [5, 7, 0.15240053907635914], [6, 7, 0.2507697996954995], [8, 9, 0.1465606610855994], [8, 10, 0.247680414841419], [8, 12, 0.24592336589326877], [9, 10, 0.15327010256956583], [9, 11, 0.24056407775175123], [9, 12, 0.15338575140593366], [9, 13, 0.2592039215032704], [9, 17, 0.24426893389235255], [10, 11, 0.1232832887720529], [10, 12, 0.24835258897302698], [10, 17, 0.13288473271498255], [10, 18, 0.2422421484186921], [11, 17, 0.22459462606233754], [12, 13, 0.15308774278089504], [12, 14, 0.2531712224795326], [13, 14, 0.15178413164640342], [13, 15, 0.23805544673935164], [13, 16, 0.23931797617867895], [14, 15, 0.1247458133959821], [14, 16, 0.1256532687270856], [15, 16, 0.21961439260959387], [17, 18, 0.1463763815855934], [17, 19, 0.24625321192821892], [17, 21, 0.24722640332512344], [18, 19, 0.15260977183675067], [18, 20, 0.2403694554898276], [18, 21, 0.15263804196042938], [18, 22, 0.24095386484723835], [18, 23, 0.2498228937420813], [18, 24, 0.24275542585198695], [19, 20, 0.12310025130101607], [19, 21, 0.2487269730102601], [19, 24, 0.13306340720566753], [19, 25, 0.24439124861981001], [20, 24, 0.22498461783867948], [21, 22, 0.14261148271519286], [21, 23, 0.151733854207495], [22, 23, 0.23953443289125953], [24, 25, 0.14568449522742966], [24, 26, 0.2421397987421541], [24, 28, 0.2453332985595212], [25, 26, 0.15154212199203948], [25, 27, 0.23869376547385443], [25, 28, 0.15321823142805788], [25, 29, 0.25327803844650226], [25, 35, 0.24421584923216363], [26, 27, 0.12312875441292488], [26, 28, 0.24814198261837936], [26, 35, 0.134088435222465], [26, 36, 0.2436311985500415], [26, 41, 0.2535109572442742], [27, 35, 0.22532490719631781], [28, 29, 0.1501002173956637], [28, 30, 0.25103984000417806], [28, 31, 0.2506296679730401], [29, 30, 0.13880557047169836], [29, 31, 0.13897768425947502], [29, 32, 0.24167057620801882], [29, 33, 0.24158976783396915], [29, 34, 0.27883028252230135], [30, 31, 0.23952278525770093], [30, 32, 0.13934816154110985], [30, 33, 0.2774124491373583], [30, 34, 0.24025925777526644], [31, 32, 0.27752584435084454], [31, 33, 0.1391495321581641], [31, 34, 0.24061463608920391], [32, 33, 0.24047376998905662], [32, 34, 0.13839621884098413], [33, 34, 0.13909989048831237], [35, 36, 0.1466645285792019], [35, 37, 0.24678305471669368], [35, 39, 0.2350328897341956], [35, 40, 0.2318695155506898], [35, 41, 0.14724373471150218], [36, 37, 0.1526441487883836], [36, 38, 0.24270999148775535], [36, 39, 0.15284629607055134], [36, 40, 0.2370917743768003], [36, 41, 0.24223826730018252], [36, 42, 0.24082453988111555], [37, 38, 0.12474299823985088], [37, 39, 0.2518125922271905], [37, 42, 0.13288561927442796], [37, 43, 0.2422500666236701], [38, 42, 0.22686535641816782], [39, 40, 0.1512202479398472], [39, 41, 0.23552553189065098], [40, 41, 0.15102156856100954], [42, 43, 0.14452410561566453], [42, 44, 0.24571476613839469], [42, 46, 0.24277816851134063], [43, 44, 0.15174735062218955], [43, 45, 0.23761520417548931], [43, 46, 0.1525868778598529], [43, 47, 0.25651150321792293], [43, 50, 0.2428777995952338], [44, 45, 0.12151175664720489], [44, 46, 0.24798443565684095], [44, 50, 0.13306442671227284], [44, 51, 0.24055382148201046], [45, 50, 0.22348362834377555], [46, 47, 0.15263183264639946], [46, 48, 0.2530599445637392], [46, 49, 0.24742925224714643], [47, 48, 0.15275856125368056], [47, 49, 0.15267298321708256], [48, 49, 0.25083337643714876], [50, 51, 0.14518192518857131], [50, 52, 0.2486164986499967], [50, 54, 0.2450329413132338], [51, 52, 0.1524080379727477], [51, 53, 0.23901033284164053], [51, ...

# %%
from mdplus.refinement import ENM

# %%
enm = ENM()
enm.fit(tsel.xyz[0], restraints=np.array(restraints))
sfac = 0.01
n_frames = 10
n_atoms = tsel.n_atoms
traj = np.zeros((n_frames, n_atoms, 3))
x = np.zeros_like(tsel.xyz[0])
x[:] = tsel.xyz[0]
for i in range(n_frames):
    dx = np.random.normal(scale=sfac, size=n_atoms*3).reshape((n_atoms, 3))
    kdt = KDTree(x + dx)
    close = kdt.query_pairs(0.1)
    print(len(close))
    full_restraints = restraints
    for c in close:
        full_restraints.append([c[0], c[1], 0.15])
    #enm = ENM()
    enm.fit(tsel.xyz[0], restraints=np.array(full_restraints))
    xtmp = enm.transform(x + dx)
    dx2 = xtmp - x
    k = 0
    while enm.result.success and k < 20:
        k+= 1
        xopt = xtmp
        dx2 *= 1.1
        xtmp = enm.transform(x + dx2)
    traj[i] = xopt
# Out:
# 5
# 3
# 4
# 5
# 4
# 8
# 2
# 1
# 3
# 4

# %%
topt2 = mdt.Trajectory(traj, tsel.topology)
topt2.save('topt2.pdb')
rmsd = mdt.rmsd(topt2, tsel[0])
print(rmsd)
# Out:
# [1.0988168 1.0988168 1.1006895 1.0971416 1.1018022 1.1018022 1.10135
#  1.10135   1.0874726 1.0874726]

# %%
kdt = KDTree(x)

# %%
close = kdt.query_pairs(0.1)
print(close)

# %%
print([c for c in nx.cycle_basis(G)])

# %%
print(bonds)

# %%
restraints = []
for b in bonds:
    restraints.append([b[0], b[1], dm[b[0], b[1]]])

# %%
sfac = 0.1
n_frames = 100
n_atoms = tsel.n_atoms
traj = np.zeros((n_frames, n_atoms, 3))
x = tsel.xyz[0].copy()
enm = ENM()
for i in range(n_frames):
    x += (np.random.rand(n_atoms, 3) - 0.5) * sfac
    kdt = KDTree(x)
    close = kdt.query_pairs(0.1)
    full_restraints = restraints
    for c in close:
        full_restraints.append([c[0], c[1], 0.15])
    enm.fit(tsel.xyz[0], restraints=np.array(full_restraints))
    x = enm.transform(x)
    if not enm.result.success:
        print('enm failed for structure', i)
    traj[i] = x
# Out:
# enm failed for structure 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [30], in <cell line: 7>()
#      13     full_restraints.append([c[0], c[1], 0.15])
#      14 enm.fit(tsel.xyz[0], restraints=np.array(full_restraints))
# ---> 15 x = enm.transform(x)
#      16 if not enm.result.success:
#      17     print('enm failed for structure', i)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/mdplus-0.0.9-py3.9-macosx-11.0-arm64.egg/mdplus/refinement.py:120, in ENM.transform(self, X)
#     118 Xout = []
#     119 for Xc in X:
# --> 120     self.result = minimize(fast.fg, Xc.flatten().astype(np.float32),
#     121                            method='TNC', jac=True,
#     122                            args=(self.restraints,
#     123                                  self.d_ref.astype(np.float32),
#     124                                  self.fc),
#     125                            options={'maxfun': self.max_its,
#     126                                     'ftol': self.tol})
#     127     Xout.append(self.result.x.reshape((-1, 3)))
#     128 Xout = np.array(Xout)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/_minimize.py:626, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     623     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                             callback=callback, **options)
#     625 elif meth == 'tnc':
# --> 626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#     628 elif meth == 'cobyla':
#     629     return _minimize_cobyla(fun, x0, args, constraints, **options)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/tnc.py:414, in _minimize_tnc(fun, x0, args, jac, bounds, eps, scale, offset, mesg_num, maxCGit, maxiter, eta, stepmx, accuracy, minfev, ftol, xtol, gtol, rescale, disp, callback, finite_diff_rel_step, maxfun, **unknown_options)
#     411     else:
#     412         maxfun = max(100, 10*len(x0))
# --> 414 rc, nf, nit, x = moduleTNC.minimize(func_and_grad, x0, low, up, scale,
#     415                                     offset, messages, maxCGit, maxfun,
#     416                                     eta, stepmx, accuracy, fmin, ftol,
#     417                                     xtol, pgtol, rescale, callback)
#     419 funv, jacv = func_and_grad(x)
#     421 return OptimizeResult(x=x, fun=funv, jac=jacv, nfev=sf.nfev,
#     422                       nit=nit, status=rc, message=RCSTRINGS[rc],
#     423                       success=(-1 < rc < 3))
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:267, in ScalarFunction.fun_and_grad(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 self._update_grad()
#     269 return self.f, self.g
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      72 def __call__(self, x, *args):
#      73     """ returns the the function value """
# ---> 74     self._compute_if_needed(x, *args)
#      75     return self._value
#
# File ~/miniconda3/envs/py39/lib/python3.9/site-packages/scipy/optimize/optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      66 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67     self.x = np.asarray(x).copy()
# ---> 68     fg = self.fun(x, *args)
#      69     self.jac = fg[1]
#      70     self._value = fg[0]
#
# KeyboardInterrupt:

# %%
topt2 = mdt.Trajectory(traj, tsel.topology)
topt2.save('topt2.pdb')
rmsd = mdt.rmsd(topt2, tsel[0])
print(rmsd)

# %%
print(enm.result.success)
# Out:
# True

# %%
print(restraints)
# Out:
# [[0, 1, 0.15038571506207546], [0, 2, 0.2486064885312728], [0, 4, 0.2499922662292181], [1, 2, 0.15355056819190213], [1, 3, 0.2414966733928919], [1, 4, 0.153625655772142], [1, 5, 0.25882544473925023], [1, 9, 0.24270156546045957], [2, 3, 0.12287220172634067], [2, 4, 0.2512865003987022], [2, 9, 0.13181693939722547], [2, 10, 0.24081680380067488], [3, 9, 0.2231233814312902], [4, 5, 0.1544037881768167], [4, 6, 0.25981550385116003], [5, 6, 0.1545964610948091], [5, 7, 0.2405622577588388], [5, 8, 0.24315429674314598], [6, 7, 0.1256052065038148], [6, 8, 0.12555418753381073], [7, 8, 0.2196452204630641], [9, 10, 0.1451512601030886], [9, 11, 0.24346973835169627], [9, 13, 0.23989368365419889], [10, 11, 0.14910285300297738], [10, 12, 0.23633065417247162], [10, 13, 0.15026847798406337], [10, 14, 0.2448518400904702], [10, 18, 0.23951539081106868], [11, 12, 0.12257806978196004], [11, 13, 0.24480490474073957], [11, 18, 0.13205916510335816], [11, 19, 0.23610832374592328], [12, 18, 0.223493050354532], [13, 14, 0.15001351569096769], [13, 15, 0.25161589466982415], [14, 15, 0.14957496222884953], [14, 16, 0.23919264714294922], [14, 17, 0.23248347482922888], [15, 16, 0.1261384486818